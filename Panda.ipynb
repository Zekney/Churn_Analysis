# %%
import pandas as pd

# %%
Sales = pd.read_csv('c:/Users/DELL/Desktop/5000-sales.csv')

# %%
Sales.head(5)
# Out:
#    ID                             Region                         Country  \
# 0   1                               Asia                     North Korea
# 1   2                               Asia                       Sri Lanka
# 2   3                               Asia                        Malaysia
# 3   4              Australia and Oceania  Federated States of Micronesia
# 4   5  Central America and the Caribbean            Antigua and Barbuda
#
#    Item Type Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 0     Cereal       Offline              L  13/05/2010  892599952  15/06/2010
# 1     Snacks       Offline              C  20/07/2015  571902596  27/07/2015
# 2     Cereal       Offline              L  31/07/2016  333942162  25/08/2016
# 3    Clothes       Offline              H  28/03/2011  932776868   10/5/2011
# 4  Baby Food        Online              M  20/12/2013  957081544   11/1/2014
#
# ...

# %%
Sales.tail(7)
# Out:
#         ID                        Region      Country   Item Type  \
# 4993  4994                        Europe      Denmark     Clothes
# 4994  4995            Sub-Saharan Africa      Liberia   Cosmetics
# 4995  4996         Australia and Oceania  New Zealand   Household
# 4996  4997  Middle East and North Africa   Azerbaijan     Clothes
# 4997  4998                          Asia      Myanmar   Baby Food
# 4998  4999                        Europe      Finland     Clothes
# 4999  5000            Sub-Saharan Africa     Tanzania  Vegetables
#
#      Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 4993       Offline              H    9/5/2012  713357150    3/6/2012
# 4994       Offline              M  17/06/2012  374724614  23/06/2012
# 4995       Offline              C    3/4/2015  217984473  20/04/2015
# 4996       Offline              L  17/08/2014  169748055   2/10/2014
# 4997       Offline              H  23/11/2016  226939189  10/12/2016
# ...

# %% [markdown]
# Tail Function Show Data rows at the Bottom based on your call

# %%
Sales.shape
# Out:
# (5000, 22)

# %% [markdown]
# Shape Function show the number of rows & columns respectively

# %%
Sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              5000 non-null   int64
#  1   Region          5000 non-null   object
#  2   Country         5000 non-null   object
#  3   Item Type       5000 non-null   object
#  4   Sales Channel   5000 non-null   object
#  5   Order Priority  5000 non-null   object
#  6   Order Date      5000 non-null   object
#  7   Order ID        5000 non-null   int64
#  8   Ship Date       5000 non-null   object
#  9   Units Sold      5000 non-null   int64
#  10  Unit Price      5000 non-null   float64
#  11  Unit Cost       5000 non-null   float64
#  12  Total Revenue   5000 non-null   float64
#  13  Total Cost      5000 non-null   float64
#  14  Total Profit    5000 non-null   float64
#  15  Tax_T_Revenue   5000 non-null   float64
#  16  Total Sales     5000 non-null   float64
# ...

# %% [markdown]
# Info function bring out the summary of columns,data types and missing values

# %%
Sales.describe()
# Out:
#                 ID      Order ID   Units Sold   Unit Price    Unit Cost  \
# count  5000.000000  5.000000e+03  5000.000000  5000.000000  5000.000000
# mean   2500.500000  5.486447e+08  5030.698200   265.745564   187.494144
# std    1443.520003  2.594671e+08  2914.515427   218.716695   176.416280
# min       1.000000  1.000909e+08     2.000000     9.330000     6.920000
# 25%    1250.750000  3.201042e+08  2453.000000    81.730000    35.840000
# 50%    2500.500000  5.523150e+08  5123.000000   154.060000    97.440000
# 75%    3750.250000  7.687709e+08  7576.250000   437.200000   263.330000
# max    5000.000000  9.998797e+08  9999.000000   668.270000   524.960000
#
#        Total Revenue    Total Cost  Total Profit  Tax_T_Revenue   Total Sales  \
# count   5.000000e+03  5.000000e+03  5.000000e+03    5000.000000  5.000000e+03
# mean    1.325738e+06  9.330932e+05  3.926446e+05   92801.648920  1.323238e+06
# std     1.475375e+06  1.150873e+06  3.829351e+05  103276.227135  1.475375e+06
# ...

# %% [markdown]
# describe shows the stastical summary of the dataset

# %%
Sales.columns
# Out:
# Index(['ID', 'Region', 'Country', 'Item Type', 'Sales Channel',
#        'Order Priority', 'Order Date', 'Order ID', 'Ship Date', 'Units Sold',
#        'Unit Price', 'Unit Cost', 'Total Revenue', 'Total Cost',
#        'Total Profit', 'Tax_T_Revenue', 'Total Sales', '4%', '7%', '11%',
#        'Lagos Revenue', 'Unnamed: 21'],
#       dtype='object')

# %% [markdown]
# Column bring out the Columns name in the dataset

# %%
Sales.dtypes
# Out:
# ID                  int64
# Region             object
# Country            object
# Item Type          object
# Sales Channel      object
# Order Priority     object
# Order Date         object
# Order ID            int64
# Ship Date          object
# Units Sold          int64
# Unit Price        float64
# Unit Cost         float64
# Total Revenue     float64
# Total Cost        float64
# Total Profit      float64
# Tax_T_Revenue     float64
# Total Sales       float64
# 4%                float64
# 7%                float64
# 11%               float64
# Lagos Revenue     float64
# Unnamed: 21        object
# dtype: object

# %% [markdown]
# dtypes shows you what is the Datatype of each Column in the dataset

# %%
#Use to Print out the list of Row index
print(Sales.loc[[0,2]])
# Out:
#    ID Region      Country Item Type Sales Channel Order Priority  Order Date  \
# 0   1   Asia  North Korea    Cereal       Offline              L  13/05/2010
# 2   3   Asia     Malaysia    Cereal       Offline              L  31/07/2016
#
#     Order ID   Ship Date  Units Sold  ...  Total Revenue  Total Cost  \
# 0  892599952  15/06/2010        9016  ...      1854591.2  1055863.76
# 2  333942162  25/08/2016        9762  ...      2008043.4  1143227.82
#
#    Total Profit  Tax_T_Revenue  Total Sales         4%          7%  \
# 0     798727.44     129821.384    1852091.2  74183.648  129821.384
# 2     864815.58     140563.038    2005543.4  80321.736  140563.038
#
#           11%  Lagos Revenue  Unnamed: 21
# 0  204005.032      1853591.2          NaN
# 2  220884.774      2007043.4          NaN
#
# [2 rows x 22 columns]

# %%
Sales.columns
# Out:
# Index(['ID', 'Region', 'Country', 'Item Type', 'Sales Channel',
#        'Order Priority', 'Order Date', 'Order ID', 'Ship Date', 'Units Sold',
#        'Unit Price', 'Unit Cost', 'Total Revenue', 'Total Cost',
#        'Total Profit', 'Tax_T_Revenue', 'Total Sales', '4%', '7%', '11%',
#        'Lagos Revenue', 'Unnamed: 21'],
#       dtype='object')

# %%
#select columns
Sales[['Item Type','Total Sales']]
# Out:
#        Item Type  Total Sales
# 0         Cereal   1852091.20
# 1         Snacks   1148258.36
# 2         Cereal   2005543.40
# 3        Clothes    899934.24
# 4      Baby Food    138414.56
# ...          ...          ...
# 4995   Household   3542672.35
# 4996     Clothes    115194.56
# 4997   Baby Food   1325977.12
# 4998     Clothes   1025824.80
# 4999  Vegetables    374947.00
#
# [5000 rows x 2 columns]

# %%
Sales['Country'].count()
# Out:
# np.int64(5000)

# %%
Sales['Order Priority'].value_counts()
# Out:
# Order Priority
# M    1321
# H    1278
# L    1227
# C    1174
# Name: count, dtype: int64

# %%
#select rows by labels
Sales.loc[0:5, ['Region','Total Sales']]
# Out:
#                               Region  Total Sales
# 0                               Asia   1852091.20
# 1                               Asia   1148258.36
# 2                               Asia   2005543.40
# 3              Australia and Oceania    899934.24
# 4  Central America and the Caribbean    138414.56
# 5  Central America and the Caribbean    328140.86

# %% [markdown]
# # Filtering Data

# %%
#This shows Rows that their UNIT SOLD value is GREATER  than 1000
Sales[Sales['Units Sold']>1000]
# Out:
#         ID                             Region                         Country  \
# 0        1                               Asia                     North Korea
# 1        2                               Asia                       Sri Lanka
# 2        3                               Asia                        Malaysia
# 3        4              Australia and Oceania  Federated States of Micronesia
# 5        6  Central America and the Caribbean                          Panama
# ...    ...                                ...                             ...
# 4995  4996              Australia and Oceania                     New Zealand
# 4996  4997       Middle East and North Africa                      Azerbaijan
# 4997  4998                               Asia                         Myanmar
# 4998  4999                             Europe                         Finland
# 4999  5000                 Sub-Saharan Africa                        Tanzania
#
# ...

# %%
#This shows Rows that their UNIT SOLD value is LESS than 1000
Sales[Sales['Units Sold']<1000]
# Out:
#         ID                             Region                 Country  \
# 4        5  Central America and the Caribbean    Antigua and Barbuda
# 10      11                             Europe  Bosnia and Herzegovina
# 13      14       Middle East and North Africa                 Morocco
# 43      44                               Asia              Kyrgyzstan
# 49      50                               Asia                  Taiwan
# ...    ...                                ...                     ...
# 4969  4970       Middle East and North Africa             Afghanistan
# 4971  4972                             Europe                  Russia
# 4981  4982                 Sub-Saharan Africa                 Eritrea
# 4986  4987                               Asia               Sri Lanka
# 4988  4989       Middle East and North Africa    United Arab Emirates
#
#             Item Type Sales Channel Order Priority  Order Date   Order ID  \
# ...

# %%
Sales[Sales['Item Type'] =='Cereal']
# Out:
#         ID                             Region         Country Item Type  \
# 0        1                               Asia     North Korea    Cereal
# 2        3                               Asia        Malaysia    Cereal
# 11      12                             Europe         Austria    Cereal
# 25      26  Central America and the Caribbean            Cuba    Cereal
# 35      36                             Europe  Czech Republic    Cereal
# ...    ...                                ...             ...       ...
# 4902  4903                             Europe         Romania    Cereal
# 4940  4941       Middle East and North Africa           Syria    Cereal
# 4945  4946                               Asia      Kazakhstan    Cereal
# 4976  4977                 Sub-Saharan Africa          Zambia    Cereal
# 4990  4991                             Europe         Ukraine    Cereal
#
#      Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# ...

# %%
Sales['Units Sold']>1000
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4       False
#         ...
# 4995     True
# 4996     True
# 4997     True
# 4998     True
# 4999     True
# Name: Units Sold, Length: 5000, dtype: bool

# %%
Sales[(Sales['Units Sold']>8000) & (Sales['Region']=='Asia')]
# Out:
#         ID Region       Country      Item Type Sales Channel Order Priority  \
# 0        1   Asia   North Korea         Cereal       Offline              L
# 2        3   Asia      Malaysia         Cereal       Offline              L
# 85      86   Asia       Myanmar      Cosmetics        Online              C
# 114    115   Asia     Singapore  Personal Care       Offline              M
# 144    145   Asia       Myanmar      Cosmetics        Online              L
# ...    ...    ...           ...            ...           ...            ...
# 4799  4800   Asia        Bhutan      Household        Online              M
# 4832  4833   Asia  Turkmenistan         Fruits        Online              M
# 4839  4840   Asia        Bhutan         Snacks        Online              L
# 4943  4944   Asia          Laos  Personal Care        Online              H
# 4983  4984   Asia   South Korea        Clothes        Online              M
#
# ...

# %%
Sales.sort_values('Country')
# Out:
#         ID                        Region      Country   Item Type  \
# 522    523  Middle East and North Africa  Afghanistan      Snacks
# 2882  2883  Middle East and North Africa  Afghanistan      Snacks
# 3523  3524  Middle East and North Africa  Afghanistan  Vegetables
# 2668  2669  Middle East and North Africa  Afghanistan      Cereal
# 213    214  Middle East and North Africa  Afghanistan   Baby Food
# ...    ...                           ...          ...         ...
# 649    650            Sub-Saharan Africa     Zimbabwe   Beverages
# 2569  2570            Sub-Saharan Africa     Zimbabwe      Fruits
# 712    713            Sub-Saharan Africa     Zimbabwe      Snacks
# 4642  4643            Sub-Saharan Africa     Zimbabwe      Cereal
# 2128  2129            Sub-Saharan Africa     Zimbabwe  Vegetables
#
#      Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 522         Online              M  19/07/2015  135500752  21/07/2015
# ...

# %%
Sales.sort_values('Item Type', ascending=True)
# Out:
#         ID                        Region       Country   Item Type  \
# 1177  1178  Middle East and North Africa       Bahrain   Baby Food
# 3131  3132  Middle East and North Africa  Saudi Arabia   Baby Food
# 410    411                        Europe       Denmark   Baby Food
# 1980  1981                          Asia     Singapore   Baby Food
# 3140  3141  Middle East and North Africa      Pakistan   Baby Food
# ...    ...                           ...           ...         ...
# 4570  4571         Australia and Oceania       Vanuatu  Vegetables
# 4563  4564                        Europe       Austria  Vegetables
# 2679  2680            Sub-Saharan Africa       Comoros  Vegetables
# 2240  2241                        Europe       Belgium  Vegetables
# 4999  5000            Sub-Saharan Africa      Tanzania  Vegetables
#
#      Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 1177       Offline              M    5/2/2010  557141864  16/02/2010
# ...

# %% [markdown]
# Grouping & Aggregation

# %%
#Group by and mean
Sales.groupby('Item Type')['Units Sold'].sum()
# Out:
# Item Type
# Baby Food          2274921
# Beverages          2208169
# Cereal             1949601
# Clothes            1983445
# Cosmetics          2141909
# Fruits             2341083
# Household          2099238
# Meat               1901197
# Office Supplies    2107628
# Personal Care      2134895
# Snacks             1921075
# Vegetables         2090330
# Name: Units Sold, dtype: int64

# %%
Sales.groupby(Sales['Item Type'] =='Cereal')['Units Sold'].sum()
# Out:
# Item Type
# False    23203890
# True      1949601
# Name: Units Sold, dtype: int64

# %%
Sales.groupby('Country')['Units Sold'].sum()
# Out:
# Country
# Afghanistan      77737
# Albania          90608
# Algeria         133198
# Andorra         185686
# Angola           75139
#                  ...
# Vatican City     99101
# Vietnam          86331
# Yemen           108499
# Zambia          139635
# Zimbabwe         93906
# Name: Units Sold, Length: 185, dtype: int64

# %%
#Multiple aggregations
Sales.groupby('Sales Channel').agg({'Units Sold':'sum', 'Total Profit':'mean'})
# Out:
#                Units Sold   Total Profit
# Sales Channel
# Offline          12569591  396809.102568
# Online           12583900  388466.841450

# %%
#Pivot table
pd.pivot_table(Sales, values='Units Sold', index='Item Type', columns='Sales Channel', aggfunc='sum')
# Out:
# Sales Channel    Offline   Online
# Item Type
# Baby Food        1203861  1071060
# Beverages        1052804  1155365
# Cereal            870699  1078902
# Clothes           958040  1025405
# Cosmetics        1097480  1044429
# Fruits           1143009  1198074
# Household        1065053  1034185
# Meat              936228   964969
# Office Supplies  1142878   964750
# Personal Care    1104954  1029941
# Snacks            914435  1006640
# Vegetables       1080150  1010180

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib as plt

# %%
import matplotlib.pyplot as plt

# %%
x = Sales['Item Type']
y = Sales['Units Sold']

# %%
plt.bar(x,y, color = "purple")
plt.show()

# %%
import pandas
import matplotlib

plt.figure(figsize=(17,7))
plt.bar(Sales['Item Type'], Sales['Total Profit'], color='darkblue', width=0.5)
plt.xlabel("Item Type")
plt.ylabel("Total Profit")
plt.title("Total Profit By Item Type")
plt.show()

# %%
import pandas
import matplotlib

plt.figure(figsize=(17,7))
plt.bar(Sales['Item Type'], Sales['Total Revenue'], color='darkgrey', width=0.5)
plt.xlabel("Item Type")
plt.ylabel("Total Revenue")
plt.title("Total Revenue By Item Type")
plt.show()

# %%
import pandas
import matplotlib

plt.hist(Sales['Region'], bins=10, color='lightcoral', edgecolor='yellow', width=0.6)
plt.xlabel("Value Range")
plt.ylabel("Frequency")
plt.title("Distribution of Region")
plt.show()

# %%
import matplotlib.pyplot as plt 

#Groupdata
sales_channel = Sales.groupby('Sales Channel')['Units Sold'].sum()

#Plot pie chart
plt.pie(
    sales_channel.values,
    labels=sales_channel.index,
    autopct="%1.1f%%",startangle=90
    )
plt.title('Sales Channel Distribution')
plt.show()

# %%
plt.pie(sales_channel.values,labels=sales_channel.index,autopct="%1.1f%%", startangle=90, colors=['red', 'green'])
plt.title('Sales Channel Distribution')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Tuesday,14th October, 2025

# %%
#Step 1: Join sales and members on 'customer_id'
merged_df = pd.merge(sales, members, on= 'customer_id', how= 'left') 
merged_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 #Step 1: Join sales and members on 'customer_id'
# ----> 2 merged_df = pd.merge(Sales, members, on= 'customer_id', how= 'left')
#       3 merged_df
#
# NameError: name 'members' is not defined

# %%
#Step 2: Join the result with menu on 'product_id'
merge = pd.merge(merged_df, menu, on='product_id', how='left')

# %% [markdown]
# Customer Churn Analysis - (Python)

# %%
#1 Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#2 Load Dataset
data_path = r'c:/Users/DELL/Desktop/Customer_Churn_Modelling.csv'
df = pd.read_csv(data_path)
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
#Create a duplicate file
DUP =df.copy()
DUP
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
#4 DUP.info() helps identify columns and types.
print('--- Info ---')
DUP.info()
# Out:
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
#5 DUP.shape will print out how many Rows and Column of the Dataset
print('--Shape--')
DUP.shape
# Out:
# --Shape--
# (10000, 14)

# %%
#6 DUP.isnull().sum() Sum the null value in each column
DUP.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
#7 DUP.columns it orints out the column 
DUP.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
#8 DUP.describe(). shows distributional summaries for numeric column
DUP.describe().T
# Out:
#                    count          mean           std          min  \
# RowNumber        10000.0  5.000500e+03   2886.895680         1.00
# CustomerId       10000.0  1.569094e+07  71936.186123  15565701.00
# CreditScore      10000.0  6.505288e+02     96.653299       350.00
# Age              10000.0  3.892180e+01     10.487806        18.00
# Tenure           10000.0  5.012800e+00      2.892174         0.00
# Balance          10000.0  7.648589e+04  62397.405202         0.00
# NumOfProducts    10000.0  1.530200e+00      0.581654         1.00
# HasCrCard        10000.0  7.055000e-01      0.455840         0.00
# IsActiveMember   10000.0  5.151000e-01      0.499797         0.00
# EstimatedSalary  10000.0  1.000902e+05  57510.492818        11.58
# Exited           10000.0  2.037000e-01      0.402769         0.00
#
#                          25%           50%           75%          max
# RowNumber            2500.75  5.000500e+03  7.500250e+03     10000.00
# ...

# %%
#9 Data cleaning 
# Drop identifier column (they don't add analytical value)
DUP_clean = DUP.drop(columns=['RowNumber', 'CustomerId', 'Surname'])

# Check for duplicates
print('Duplicates:', DUP_clean.duplicated().sum())

# Ensure no missing values remain
DUP_clean.info()
# Out:
# Duplicates: 0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CreditScore      10000 non-null  int64
#  1   Geography        10000 non-null  object
#  2   Gender           10000 non-null  object
#  3   Age              10000 non-null  int64
#  4   Tenure           10000 non-null  int64
#  5   Balance          10000 non-null  float64
#  6   NumOfProducts    10000 non-null  int64
#  7   HasCrCard        10000 non-null  int64
#  8   IsActiveMember   10000 non-null  int64
#  9   EstimatedSalary  10000 non-null  float64
#  10  Exited           10000 non-null  int64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 859.5+ KB

# %% [markdown]
# Data Exploration

# %%
#10 Univariate Analysis (Histograms)
numeric_cols = ['CreditScore','Age','Tenure','Balance','NumOfProducts','EstimatedSalary']

for col in numeric_cols:
    plt.figure(figsize=(6,3))
    plt.hist(DUP_clean[col], bins=20, color='skyblue', edgecolor='black')
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('count')
    plt.tight_layout()
    plt.show()

# %%
#11 Categorical Feature C
cat_cols = ['Geography','Gender','HasCrCard','IsActiveMember','Exited']

for col in cat_cols:
    plt.figure(figsize=(5,3))
    counts = DUP_clean[col].value_counts()
    plt.bar(counts.index.astype(str), counts.values, color='Yellow', edgecolor='black')
    plt.title(f'C
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    ount by {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.tight_layout()
    plt.show()
